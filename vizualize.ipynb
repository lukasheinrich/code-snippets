# %%
# !pip install wand
# Out:
# ...
#     100% |################################| 71kB 7.4MB/s
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/8e/21/8d/53672efb50d7ef28ae31abd944323227109a59e6668afdaff9
# Successfully built wand
# ...

# %%
from wand.image import Image as WImage
WImage(filename='/workdir/adage_stages.pdf', resolution=100)
# Out:
# <wand.image.Image: f67c5da 'PDF' (239x461)>

# %%
from wand.image import Image as WImage
WImage(filename='/workdir/adage_workflow_instance.pdf', resolution=100)
# Out:
# <wand.image.Image: 731d906 'PDF' (819x861)>

# %%
from IPython.display import HTML
HTML('<img src="/workdir/workflow.gif">')
# Out:
# <img src="/workdir/workflow.gif">

# %%
import base64
imgstring = base64.b64encode(open('/workdir/workflow.gif').read())

# %%
HTML('<img alt="Embedded Image" src="data:image/png;base64,{}" />'.format(imgstring))
# Out:
# <img alt="Embedded Image" src="data:image/png;base64,..." />
