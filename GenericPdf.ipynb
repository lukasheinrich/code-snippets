# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.07/07

# %%
ROOT.RooFit
# Out:
# ROOT.RooFit
# RooFit v3.60 -- Developed by Wouter Verkerke and David Kirkby
#                 Copyright (C) 2000-2013 NIKHEF, University of California & Stanford University
#                 All rights reserved, please read http://roofit.sourceforge.net/license.txt

# %%
x = ROOT.RooRealVar('x','the x', -5,5)
pdf = ROOT.RooGenericPdf('mypdf','mypdf','exp(-x^2)',ROOT.RooArgList(x))

# %%
data = pdf.generate(ROOT.RooArgSet(x),2000)
# Out:
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(mypdf_Int[x]) using numeric integrator RooIntegrator1D to calculate Int(x)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(mypdf_Int[x]) using numeric integrator RooIntegrator1D to calculate Int(x)

# %%
c = ROOT.TCanvas()
hist = super(ROOT.RooDataSet,data).createHistogram('extracedhist',x,ROOT.RooFit.Binning(10,5,5))
hist.Draw('h')
c.Draw()

# %%
c = ROOT.TCanvas()
h = data.
h.Draw()
c.Draw()
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-19-d16dbbdaf38e> in <module>()
#       1 c = ROOT.TCanvas()
# ----> 2 h = data.createHistogram(x,ROOT.RooAbsReal())
#       3 h.Draw()
#       4 c.Draw()
#
# TypeError: none of the 4 overloaded methods succeeded. Full details:
#   RooAbsReal is abstract and can not be instantiated
#   RooAbsReal is abstract and can not be instantiated
#   RooAbsReal is abstract and can not be instantiated
#   RooAbsReal is abstract and can not be instantiated

# %%
c = ROOT.TCanvas()
fr = x.frame()
data.plotOn(fr)
# Out:
# <ROOT.RooPlot object ("frame_x_7fe1d16fa4f0") at 0x7fe1d16fa4f0>

# %%
fr.Draw()
c.Draw()

# %%
pdf = ROOT.RooGenericPdf('mypdf','mypdf','1-abs(x/5)',ROOT.RooArgList(x))

# %%
data = pdf.generate(ROOT.RooArgSet(x),10000)
# Out:
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(mypdf_Int[x]) using numeric integrator RooIntegrator1D to calculate Int(x)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(mypdf_Int[x]) using numeric integrator RooIntegrator1D to calculate Int(x)

# %%
c = ROOT.TCanvas()
fr = x.frame()

# %%
data.plotOn(fr)
fr.Draw()
c.Draw()
