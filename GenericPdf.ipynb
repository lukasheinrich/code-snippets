# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.07/07

# %%
ROOT.RooFit
# Out:
# ROOT.RooFit
# RooFit v3.60 -- Developed by Wouter Verkerke and David Kirkby
#                 Copyright (C) 2000-2013 NIKHEF, University of California & Stanford University
#                 All rights reserved, please read http://roofit.sourceforge.net/license.txt

# %%
x = ROOT.RooRealVar('x','the x', -5,5)
pdf = ROOT.RooGenericPdf('mypdf','mypdf','exp(-x^2)',ROOT.RooArgList(x))

# %%
data = pdf.generate(ROOT.RooArgSet(x),2000)
# Out:
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(mypdf_Int[x]) using numeric integrator RooIntegrator1D to calculate Int(x)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(mypdf_Int[x]) using numeric integrator RooIntegrator1D to calculate Int(x)

# %%
c = ROOT.TCanvas()
fr = x.frame()
data.plotOn(fr)
# Out:
# <ROOT.RooPlot object ("frame_x_7f8a84d21b20") at 0x7f8a84d21b20>

# %%
data.plotOn(fr)
fr.Draw()
c.Draw()

# %%
pdf = ROOT.RooGenericPdf('mypdf','mypdf','abs(x)',ROOT.RooArgList(x))

# %%
data = pdf.generate(ROOT.RooArgSet(x),2000)
# Out:
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(mypdf_Int[x]) using numeric integrator RooIntegrator1D to calculate Int(x)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(mypdf_Int[x]) using numeric integrator RooIntegrator1D to calculate Int(x)

# %%
c = ROOT.TCanvas()
fr = x.frame()
data.plotOn(fr)
# Out:
# <ROOT.RooPlot object ("frame_x_7f8a84ad9020") at 0x7f8a84ad9020>

# %%
data.plotOn(fr)
fr.Draw()
c.Draw()
